# %%
import k2
import torch

# %%
import graphviz
ss = """
digraph WFST {
    margin=0;
    graph [center=1 nodesep=0.2 orientation=Portrait rankdir=LR ranksep=0 size="8.5,11"]
        0 [label=0 fontsize=14 shape=circle style=bold]
        0 -> 0 [label="blk:ε/0"]
        1 [label=1 fontsize=14 shape=circle style=bold]
        0 -> 1 [label="A:A/0"]
        2 [label=2 fontsize=14 shape=circle style=bold]
        1 -> 2 [label="blk:ε/0"]
        3 [label=3 fontsize=14 shape=circle style=bold]
        1 -> 3 [label="B:B/0"]
        2 -> 2 [label="blk:ε/0"]
        2 -> 3 [label="B:B/0"]
        4 [label=4 fontsize=14 shape=circle style=bold]
        3 -> 4 [label="blk:ε/0"]
        5 [label=5 fontsize=14 shape=doublecircle style=bold]
        3 -> 5 [label="-1:-1/0"]
        4 -> 4 [label="blk:ε/0"]
        4 -> 5 [label="-1:-1/0"]
}
"""
source = graphviz.Source(ss)
source.render('HL_hard', format='pdf')
source

# %%
import graphviz
ss = """
digraph WFST {
    margin=0;
    graph [center=1 nodesep=0.2 orientation=Portrait rankdir=LR ranksep=0 size="8.5,11"]
        0 [label=0 fontsize=14 shape=circle style=bold]
        0 -> 0 [label="blk:ε/0"]
        1 [label=1 fontsize=14 shape=circle style=bold]
        0 -> 1 [label="A:A/0"]
        2 [label=2 fontsize=14 shape=circle style=bold]
        1 -> 2 [label="A:ε/0"]
        3 [label=3 fontsize=14 shape=circle style=bold]
        1 -> 3 [label="blk:ε/0"]
        4 [label=4 fontsize=14 shape=circle style=bold]
        1 -> 4 [label="B:B/0"]
        2 -> 3 [label="blk:ε/0"]
        2 -> 4 [label="B:B/0"]
        3 -> 3 [label="blk:ε/0"]
        3 -> 4 [label="B:B/0"]
        5 [label=5 fontsize=14 shape=circle style=bold]
        4 -> 5 [label="B:ε/0"]
        6 [label=6 fontsize=14 shape=circle style=bold]
        4 -> 6 [label="blk:ε/0"]
        7 [label=7 fontsize=14 shape=doublecircle style=bold]
        4 -> 7 [label="-1:-1/0"]
        5 -> 6 [label="blk:ε/0"]
        5 -> 7 [label="-1:-1/0"]
        6 -> 6 [label="blk:ε/0"]
        6 -> 7 [label="-1:0/0"]
}
"""
source = graphviz.Source(ss)
source.render('HL_hard2', format='pdf')
source
